# %%
# clone visual-chatgpt
# !git clone https://github.com/microsoft/visual-chatgpt

# %%
# install moudles
# %cd visual-chatgpt
# !pip install -r requirements.txt

# %%
# !mkdir ./image

# %%
# %env OPENAI_API_KEY={'yourkey'}

# %%
# !ls
# !sed -i '$s/.*/    demo.launch(server_name="0.0.0.0", server_port=7868, share=True)/' visual_chatgpt.py

# %%
# !python visual_chatgpt.py --load="ImageCaptioning_cuda:0,Text2Image_cuda:0,Image2Canny_cuda:0"
